# %% [markdown]
# <a href="https://colab.research.google.com/github/TheThirdKnife/Student/blob/main/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4%20%D0%B1%D0%BB%D0%B8%D0%B6%D0%B0%D0%B9%D1%88%D0%B8%D1%85%20%D1%81%D0%BE%D1%81%D0%B5%D0%B4%D0%B5%D0%B9%20(%D1%80%D0%B5%D0%B3%D1%80%D0%B5%D1%81%D1%81%D0%B8%D1%8F)%20(StudentPerformanceFactors).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Импортируем библиотеки
import pandas as pd

# Загружаем набор данных
StudentPerformanceFactors = pd.read_csv('/content/drive/MyDrive/StudentPerformanceFactors.csv')
StudentPerformanceFactors.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
# Сохраняем в новый фрейм столбцы предикторов
X=StudentPerformanceFactors.drop(['Exam_Score'], axis=1)
# Сохраняем в переменную y отклик
y=StudentPerformanceFactors.Exam_Score
# Преобразуем категориальны переменные в dummy
X=pd.get_dummies(X, drop_first=True)

# %%
# Проведем разбиение исходных наблюдений предикторов и отклика
# на обучающую выборку и тестовую
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.neighbors import KNeighborsRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from os import XATTR_SIZE_MAX
knn = KNeighborsRegressor(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
knn_pred = knn.predict(X_test)
X_test1 = X_test
X_test1['knn'] = knn_pred
X_test1['churn'] = y_test
X_test1.head()
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 5753             12          79            5               56
# 3419             17          64            7               68
# 6352             12          92            7               90
# 3086             20          84            7               74
# 3961             31          94            5               92
#
#       Tutoring_Sessions  Physical_Activity  Parental_Involvement_Low  \
# 5753                  1                  5                     False
# 3419                  5                  3                      True
# 6352                  2                  5                     False
# 3086                  1                  3                      True
# 3961                  1                  4                      True
#
#       Parental_Involvement_Medium  Access_to_Resources_Low  \
# 5753                        False                    False
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/TheThirdKnife/Student/blob/main/%D0%9B%D0%B8%D0%BD%D0%B5%D0%B9%D0%BD%D0%B0%D1%8F%20%D1%80%D0%B5%D0%B3%D1%80%D0%B5%D1%81%D1%81%D0%B8%D1%8F%20(StudentPerformanceFactors).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Импортируем библиотеки
import pandas as pd

# Загружаем набор данных
StudentPerformanceFactors = pd.read_csv('/content/drive/MyDrive/StudentPerformanceFactors.csv')
StudentPerformanceFactors.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
# 3             Yes                  1        Medium          Medium
# 4             Yes                  3        Medium            High
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74
# 3              High School           Moderate    Male          71
# 4                  College               Near  Female          70

# %%
# Сохраняем в новый фрейм столбцы предикторов
X=StudentPerformanceFactors.drop(['Exam_Score'], axis=1)
# Сохраняем в переменную y отклик
y=StudentPerformanceFactors.Exam_Score
# Преобразуем категориальны переменные в dummy
X=pd.get_dummies(X, drop_first=True)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 41.82141609603191

# %%
lr.coef_
# Out:
# array([ 2.94647127e-01,  1.98785871e-01, -1.15615643e-03,  4.88495239e-02,
#         4.97293677e-01,  1.88095944e-01, -1.98778885e+00, -1.06143973e+00,
#        -2.05423692e+00, -1.00469937e+00,  5.61909363e-01, -1.06319966e+00,
#        -5.41521891e-01,  9.26934968e-01, -1.08215525e+00, -5.86306287e-01,
#        -1.02920421e+00, -5.23902799e-01,  2.57561720e-02,  5.16357708e-01,
#         1.02448019e+00, -8.55775636e-01, -4.72134982e-01,  5.09971257e-01,
#         3.51388547e-01,  8.75052203e-01, -3.95748352e-02])

# %%
lr.score(X,y)
# Out:
# 0.7270282169570199

# %%
klr=pd.DataFrame()
klr['name']=X.columns
klr['coef']=lr.coef_
klr
# Out:
#                                      name      coef
# 0                           Hours_Studied  0.294647
# 1                              Attendance  0.198786
# 2                             Sleep_Hours -0.001156
# 3                         Previous_Scores  0.048850
# 4                       Tutoring_Sessions  0.497294
# 5                       Physical_Activity  0.188096
# 6                Parental_Involvement_Low -1.987789
# 7             Parental_Involvement_Medium -1.061440
# 8                 Access_to_Resources_Low -2.054237
# 9              Access_to_Resources_Medium -1.004699
# 10         Extracurricular_Activities_Yes  0.561909
# 11                   Motivation_Level_Low -1.063200
# 12                Motivation_Level_Medium -0.541522
# 13                    Internet_Access_Yes  0.926935
# 14                      Family_Income_Low -1.082155
# 15                   Family_Income_Medium -0.586306
# 16                    Teacher_Quality_Low -1.029204
# 17                 Teacher_Quality_Medium -0.523903
# 18                     School_Type_Public  0.025756
# 19                 Peer_Influence_Neutral  0.516358
# 20                Peer_Influence_Positive  1.024480
# 21              Learning_Disabilities_Yes -0.855776
# 22   Parental_Education_Level_High School -0.472135
# 23  Parental_Education_Level_Postgraduate  0.509971
# 24            Distance_from_Home_Moderate  0.351389
# 25                Distance_from_Home_Near  0.875052
# 26                            Gender_Male -0.039575

# %%
lr.predict(X)
# Out:
# array([67.10199028, 60.90003374, 74.21668393, ..., 67.75613163,
#        68.29584865, 64.01073164])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
results = smf.ols('Exam_Score ~ Hours_Studied', data=StudentPerformanceFactors).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Exam_Score   R-squared:                       0.198
# Model:                            OLS   Adj. R-squared:                  0.198
# Method:                 Least Squares   F-statistic:                     1635.
# Date:                Wed, 20 Nov 2024   Prob (F-statistic):          1.29e-319
# Time:                        08:36:39   Log-Likelihood:                -17620.
# No. Observations:                6607   AIC:                         3.524e+04
# Df Residuals:                    6605   BIC:                         3.526e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        61.4570      0.149    411.921      0.000      61.165      61.749
# Hours_Studied     0.2893      0.007     40.436      0.000       0.275       0.303
# ==============================================================================
# Omnibus:                     3818.585   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            83929.561
# Skew:                           2.332   Prob(JB):                         0.00
# Kurtosis:                      19.826   Cond. No.                         72.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
StudentPerformanceFactors = pd.get_dummies(StudentPerformanceFactors, drop_first=True)
StudentPerformanceFactors.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score',
#        'Parental_Involvement_Low', 'Parental_Involvement_Medium',
#        'Access_to_Resources_Low', 'Access_to_Resources_Medium',
#        'Extracurricular_Activities_Yes', 'Motivation_Level_Low',
#        'Motivation_Level_Medium', 'Internet_Access_Yes', 'Family_Income_Low',
#        'Family_Income_Medium', 'Teacher_Quality_Low', 'Teacher_Quality_Medium',
#        'School_Type_Public', 'Peer_Influence_Neutral',
#        'Peer_Influence_Positive', 'Learning_Disabilities_Yes',
#        'Parental_Education_Level_High School',
#        'Parental_Education_Level_Postgraduate', 'Distance_from_Home_Moderate',
#        'Distance_from_Home_Near', 'Gender_Male'],
#       dtype='object')

# %%
results = smf.ols('Exam_Score ~ Hours_Studied + Parental_Involvement_Medium + Extracurricular_Activities_Yes + Teacher_Quality_Medium',
                  data = StudentPerformanceFactors).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Exam_Score   R-squared:                       0.206
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     428.4
# Date:                Wed, 20 Nov 2024   Prob (F-statistic):               0.00
# Time:                        08:40:34   Log-Likelihood:                -17588.
# No. Observations:                6607   AIC:                         3.519e+04
# Df Residuals:                    6602   BIC:                         3.522e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                 61.4736      0.171    359.634      0.000      61.139      61.809
# Parental_Involvement_Medium[T.True]       -0.2922      0.085     -3.424      0.001      -0.459      -0.125
# Extracurricular_Activities_Yes[T.True]     0.5381      0.087      6.188      0.000       0.368       0.709
# Teacher_Quality_Medium[T.True]            -0.3315      0.087     -3.816      0.000      -0.502      -0.161
# Hours_Studied                              0.2897      0.007     40.678      0.000       0.276       0.304
# ==============================================================================
# Omnibus:                     3826.228   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            84588.153
# Skew:                           2.336   Prob(JB):                         0.00
# Kurtosis:                      19.895   Cond. No.                         86.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
